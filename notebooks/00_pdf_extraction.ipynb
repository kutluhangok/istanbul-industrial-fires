# %% [markdown]
# # 00 PDF Extraction
#
# DSA 210 industrial fire and explosion analysis project.

# %% [markdown]
# Extracts Ek-1 incident tables from KMO annual PDFs. 2017-2021 use detected table cells; 2022-2023 use coordinate-based word extraction; 2024 is logged as requiring OCR because appendix pages have no extractable text layer.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from src.pdf_extractor import extract_all

raw = extract_all(output_path=Path("../data/raw/kmo_incidents_raw.xlsx"))
raw.groupby("source_year").size()

# %%
raw.head()

# %%
import pandas as pd
log = pd.read_csv("../data/raw/extraction_log.csv")
log
